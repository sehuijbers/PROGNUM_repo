# %%
n = input(f"input a value that you want to be  higher than all generated Fabonacci numbers")
N = int(n) # To make sure N is an integer
m = input(f"input a value that you through which all finonacci numbers have to be devided")
M = int(m)

s = 0
step = 1
k = 1

while k < 100:
    s, step = step , s+ step 
    k+=1
    if step < N and step/M - int(step/M) == 0: # only print when the value is smaller than N and dividable by M
        print (step)
