# %%
from math import *
a = input("value for a")
b = input("value for b")
c = input("value for c")

a = int(a)
b = int(b)
c = int(c)

D = b**2 - 4*a*c

if D > 0:
    x1 = (-b + sqrt(D))/(2*a)
    x2 = (-b -sqrt(D))/(2*a)
    b = f"the answers are {x1} and {x2}"
    print(b)
    

elif D==0:
    x = (-b + sqrt(D))/(2*a)
    b = f"the answer is {x1}"
    print(b)

else:
    print ("the asnwer doesnt exist")
# Out:
# value for a 1
# value for b -5
# value for c 6
# the answers are 3.0 and 2.0
