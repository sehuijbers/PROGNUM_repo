# %% [markdown]
# jupyter notebook --browser firefox
# Answers for Week 1
#
# * Name: Sietske Huijbers
# * Username: sehuijbers
# * Student s-number: s6479979
# * Group (AS1, etc.): AS4

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
x=6*5*4*3*2*1
print("x:",x)
# Out:
# x: 720

# %%
f=2.42e28
from scipy.constants import h
from scipy.constants import c
print("h:",h)
print("c:",c)
print("f:",f)
# Out:
# h: 6.62607015e-34
# c: 299792458.0
# f: 2.42e+28

# %%
l=c/f
print("l:",l)
# Out:
# l: 1.2388118099173553e-20

# %%
E=h*c/l
print("E:",E)
# Out:
# E: 1.6035089763e-05

# %% [markdown]
# Question 5

# %%
massmoon = 7.342e22
massearth = 5.9722e24
distance = 38500000.6
from scipy.constants import G
print("massmoon:",massmoon)
print("massearth:",massearth)
print("distance:",distance)
print("G:",G)
# Out:
# massmoon: 7.342e+22
# massearth: 5.9722e+24
# distance: 38500000.6
# G: 6.6743e-11

# %%
Fg=G*massmoon*massearth/distance**2
print("Fg:",Fg)
# Out:
# Fg: 1.97439014419725e+22

# %%
x1 = 10
x2 = 22/7
print(x1, end=" ")
print(x2, end=" ")
# Out:
# 10 3.142857142857143

# %%
x1 = 10
x2 = 22/7
print(x2, end="")
# Out:
# 3.142857142857143

# %% [markdown]
# Task 1.11

# %% [markdown]
# ![Screenshot from 2026-02-13 12-16-43.png](attachment:db1c2482-6af4-49a0-859b-bd7984fcdc8f.png)

# %% [markdown]
# Task 1.12

# %% [markdown]
# ![Screenshot from 2026-02-13 12-44-24.png](attachment:6d63214f-9bb6-4a01-9442-f17fd899db68.png)

# %% [markdown]
# 1.19
# 1. it lists everything starting with zero or more caracters (except /) and than has  a number between 0  and 9, then a dot and then  the c or o or both
# 2. that it can be any nummer or letter given in between the square buttons, doesnt have to be all of them.

# %% [markdown]
# 2.26

# %% [markdown]
# ![Screenshot from 2026-02-20 13-20-54.png](attachment:84b12e31-db77-4771-941c-5dc028edb56c.png)
