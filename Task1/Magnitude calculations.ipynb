# %%
# Sirius data
apparentMagnitude = -1.46
absoluteMagnitude = 1.45

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = apparentMagnitude
M = absoluteMagnitude

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164
b = f"An approximation for the distance to Sirius is: {d}"
print(b)
# Out:
# An approximation for pi is: 8.53957042692737

# %%
apparentMagnitude = s1 = input("Enter a apparent Magnitude: ")
x1 = int(s1)
print(x1, type(x1))
absoluteMagnitude = s2 = input ("Enter an absolute Magnitude: ")
x2 = int(s2)
print(x2, type(x2))



# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = int(apparentMagnitude)
M = int(absoluteMagnitude)

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164
b = f"An approximation for the distamce knowing the magnitudes is: {d}"
print(b)
# Out:
# Enter a apparent Magnitude:  2
# 2 <class 'int'>
# Enter an absolute Magnitude:  5
# 5 <class 'int'>
# An approximation for the distamce knowing the magnitudes is: 8.192869260468907
